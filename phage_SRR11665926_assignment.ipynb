# %% [markdown]
# <a href="https://colab.research.google.com/github/atienoodongo/Phage-hunters-cohoort-004/blob/main/phage_SRR11665926_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# 📢 Announcement 📢
# condacolab==0.2 will be released soon! Try it with:
#
#     !pip install -q https://github.com/conda-incubator/condacolab/archive/main.zip
#     import condacolab
#     condacolab.install()
#
# 0.2.x introduces a new installation method based on Pixi, with customizable Python versions.
# This may be breaking for your workflow. If that's the case, please report it at
# https://github.com/conda-incubator/condacolab and pin your `pip install` command to
# condacolab==0.1 as a workaround.
#
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/26.3.2-3/Miniforge3-26.3.2-3-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...

# %%
# !conda--version
# Out:
# /bin/bash: line 1: conda--version: command not found

# %%
# !conda --version
# Out:
# conda 26.3.2

# %%
# !mamba create -y -n phage_env -c bioconda -c conda-forge sra-tools fastqc fastp unicycler quast seqkit
# Out:
# [+] 0.0s
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# bioconda/linux-64      5%
# bioconda/noarch        2%[+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     2%
# bioconda/linux-64     45%
# bioconda/noarch       37%[+] 0.3s
# conda-forge/linux-64   4%
# conda-forge/noarch     6%
# bioconda/linux-64     67%
# bioconda/noarch       58%[+] 0.4s
# conda-forge/linux-64   7%
# conda-forge/noarch    11%
# bioconda/linux-64     92%
# bioconda/noarch       86%bioconda/linux-64
# bioconda/noarch
# [+] 0.5s
# conda-forge/linux-64   9%
# conda-forge/noarch    16%[+] 0.6s
# conda-forge/linux-64  16%
# conda-forge/noarch    30%[+] 0.7s
# conda-forge/linux-64  23%
# conda-forge/noarch    44%[+] 0.8s
# conda-forge/linux-64  23%
# conda-forge/noarch    44%[+] 0.9s
# conda-forge/linux-64  23%
# conda-forge/noarch    44%[+] 1.0s
# conda-forge/linux-64  23%
# conda-forge/noarch    44%[+] 1.1s
# conda-forge/linux-64  23%
# conda-forge/noarch    45%[+] 1.2s
# ...

# %%
# !conda list phage_env
# Out:
# CondaValueError: No packages match 'phage_env'.

# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     /usr/local
# phage_env                /usr/local/envs/phage_env

# %%
# !mkdir raw_data qc_initial trimmed assembly quast seqkit blast annotation
